# %%
#Load libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#Load CSV

data = pd.read_csv('breast-cancer-wisconsin.data.csv')
temp = data
data.head()
# Out:
#         id  slump_thickness  Uniformity_of_Cell_Size  \
# 0  1000025                5                        1
# 1  1002945                5                        4
# 2  1015425                3                        1
# 3  1016277                6                        8
# 4  1017023                4                        1
#
#    Uniformity_of_Cell_Shape  Marginal_Adhesion  Single_Epithelial_Cell_Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#   Bare_Nuclei  Bland_Chromatin  Normal_Nucleoli  Mitoses  Class
# 0           1                3                1        1      2
# 1          10                3                2        1      2
# 2           2                3                1        1      2
# 3           4                3                7        1      2
# 4           1                3                1        1      2

# %%
data.Class[data.Class == 2] = "B" 
data.Class[data.Class == 4] = "M" 

print "Features considered are: "
print "-------------------------"
for col in data.columns:
    print col
# Out:
# Features considered are:
# -------------------------
# id
# slump_thickness
# Uniformity_of_Cell_Size
# Uniformity_of_Cell_Shape
# Marginal_Adhesion
# Single_Epithelial_Cell_Size
# Bare_Nuclei
# Bland_Chromatin
# Normal_Nucleoli
# Mitoses
# Class
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
target = data['Class']
ax = sns.countplot(target,label="Count")
B, M = target.value_counts()
print 'Number of Benign: ',B
print 'Number of Malignant : ',M
# Out:
# Number of Benign:  458
# Number of Malignant :  241

# %%
features_not_required = ['id','Class']
x = data.drop(features_not_required,axis = 1 )
x.describe()
# Out:
#        slump_thickness  Uniformity_of_Cell_Size  Uniformity_of_Cell_Shape  \
# count       699.000000               699.000000                699.000000
# mean          4.417740                 3.134478                  3.207439
# std           2.815741                 3.051459                  2.971913
# min           1.000000                 1.000000                  1.000000
# 25%           2.000000                 1.000000                  1.000000
# 50%           4.000000                 1.000000                  1.000000
# 75%           6.000000                 5.000000                  5.000000
# max          10.000000                10.000000                 10.000000
#
#        Marginal_Adhesion  Single_Epithelial_Cell_Size  Bland_Chromatin  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     2.000000         2.000000
# 50%             1.000000                     2.000000         3.000000
# 75%             4.000000                     4.000000         5.000000
# max            10.000000                    10.000000        10.000000
#
#        Normal_Nucleoli     Mitoses
# count       699.000000  699.000000
# mean          2.866953    1.589413
# std           3.053634    1.715078
# min           1.000000    1.000000
# 25%           1.000000    1.000000
# 50%           1.000000    1.000000
# 75%           4.000000    1.000000
# max          10.000000   10.000000

# %%
print data

df = pd.melt(data, id_vars=['Class'], value_vars=['Mitosis', 'slump_thickness'])
print df
sns.violinplot(x='variable', y='value', hue='Class', data=df)
plt.show()
# Out:
#           id  slump_thickness  Uniformity_of_Cell_Size  \
# 0    1000025                5                        1
# 1    1002945                5                        4
# 2    1015425                3                        1
# 3    1016277                6                        8
# 4    1017023                4                        1
# 5    1017122                8                       10
# 6    1018099                1                        1
# 7    1018561                2                        1
# 8    1033078                2                        1
# 9    1033078                4                        2
# 10   1035283                1                        1
# 11   1036172                2                        1
# 12   1041801                5                        3
# 13   1043999                1                        1
# 14   1044572                8                        7
# 15   1047630                7                        4
# 16   1048672                4                        1
# 17   1049815                4                        1
# 18   1050670               10                        7
# 19   1050718                6                        1
# 20   1054590                7                        3
# 21   1054593               10                        5
# 22   1056784                3                        1
# 23   1057013                8                        4
# 24   1059552                1                        1
# 25   1065726                5                        2
# 26   1066373                3                        2
# 27   1066979                5                        1
# 28   1067444                2                        1
# 29   1070935                1                        1
# ..       ...              ...                      ...
# 669  1350423                5                       10
# 670  1352848                3                       10
# 671  1353092                3                        2
# 672  1354840                2                        1
# 673  1354840                5                        3
# 674  1355260                1                        1
# 675  1365075                4                        1
# 676  1365328                1                        1
# 677  1368267                5                        1
# 678  1368273                1                        1
# 679  1368882                2                        1
# 680  1369821               10                       10
# 681  1371026                5                       10
# 682  1371920                5                        1
# 683   466906                1                        1
# 684   466906                1                        1
# 685   534555                1                        1
# 686   536708                1                        1
# 687   566346                3                        1
# 688   603148                4                        1
# 689   654546                1                        1
# 690   654546                1                        1
# 691   695091                5                       10
# 692   714039                3                        1
# 693   763235                3                        1
# 694   776715                3                        1
# 695   841769                2                        1
# 696   888820                5                       10
# 697   897471                4                        8
# 698   897471                4                        8
#
#      Uniformity_of_Cell_Shape  Marginal_Adhesion  Single_Epithelial_Cell_Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# 2                           1                  1                            2
# 3                           8                  1                            3
# 4                           1                  3                            2
# 5                          10                  8                            7
# 6                           1                  1                            2
# 7                           2                  1                            2
# 8                           1                  1                            2
# 9                           1                  1                            2
# 10                          1                  1                            1
# 11                          1                  1                            2
# 12                          3                  3                            2
# 13                          1                  1                            2
# 14                          5                 10                            7
# 15                          6                  4                            6
# 16                          1                  1                            2
# 17                          1                  1                            2
# 18                          7                  6                            4
# 19                          1                  1                            2
# 20                          2                 10                            5
# 21                          5                  3                            6
# 22                          1                  1                            2
# 23                          5                  1                            2
# 24                          1                  1                            2
# 25                          3                  4                            2
# 26                          1                  1                            1
# 27                          1                  1                            2
# 28                          1                  1                            2
# 29                          3                  1                            2
# ..                        ...                ...                          ...
# 669                        10                  8                            5
# 670                         7                  8                            5
# 671                         1                  2                            2
# 672                         1                  1                            2
# 673                         2                  1                            3
# 674                         1                  1                            2
# 675                         4                  1                            2
# 676                         2                  1                            2
# 677                         1                  1                            2
# 678                         1                  1                            2
# 679                         1                  1                            2
# 680                        10                 10                            5
# 681                        10                 10                            4
# 682                         1                  1                            2
# 683                         1                  1                            2
# 684                         1                  1                            2
# 685                         1                  1                            2
# 686                         1                  1                            2
# 687                         1                  1                            2
# 688                         1                  1                            2
# 689                         1                  1                            2
# 690                         1                  3                            2
# 691                        10                  5                            4
# 692                         1                  1                            2
# 693                         1                  1                            2
# 694                         1                  1                            3
# 695                         1                  1                            2
# 696                        10                  3                            7
# 697                         6                  4                            3
# 698                         8                  5                            4
#
#     Bare_Nuclei  Bland_Chromatin  Normal_Nucleoli  Mitoses Class
# 0             1                3                1        1     B
# 1            10                3                2        1     B
# 2             2                3                1        1     B
# 3             4                3                7        1     B
# 4             1                3                1        1     B
# 5            10                9                7        1     M
# 6            10                3                1        1     B
# 7             1                3                1        1     B
# 8             1                1                1        5     B
# 9             1                2                1        1     B
# 10            1                3                1        1     B
# 11            1                2                1        1     B
# 12            3                4                4        1     M
# 13            3                3                1        1     B
# 14            9                5                5        4     M
# 15            1                4                3        1     M
# 16            1                2                1        1     B
# 17            1                3                1        1     B
# 18           10                4                1        2     M
# 19            1                3                1        1     B
# 20           10                5                4        4     M
# 21            7                7               10        1     M
# 22            1                2                1        1     B
# 23            ?                7                3        1     M
# 24            1                3                1        1     B
# 25            7                3                6        1     M
# 26            1                2                1        1     B
# 27            1                2                1        1     B
# 28            1                2                1        1     B
# 29            1                1                1        1     B
# ..          ...              ...              ...      ...   ...
# 669           5                7               10        1     M
# 670           8                7                4        1     M
# 671           1                3                1        1     B
# 672           1                3                1        1     B
# 673           1                1                1        1     B
# 674           1                2                1        1     B
# 675           1                1                1        1     B
# 676           1                2                1        1     B
# 677           1                1                1        1     B
# 678           1                1                1        1     B
# 679           1                1                1        1     B
# 680          10               10               10        7     M
# 681          10                5                6        3     M
# 682           1                3                2        1     B
# 683           1                1                1        1     B
# 684           1                1                1        1     B
# 685           1                1                1        1     B
# 686           1                1                1        1     B
# 687           1                2                3        1     B
# 688           1                1                1        1     B
# 689           1                1                1        8     B
# 690           1                1                1        1     B
# 691           5                4                4        1     M
# 692           1                1                1        1     B
# 693           1                2                1        2     B
# 694           2                1                1        1     B
# 695           1                1                1        1     B
# 696           3                8               10        2     M
# 697           4               10                6        1     M
# 698           5               10                4        1     M
#
# [699 rows x 11 columns]
#      Class         variable  value
# 0        B          Mitosis    NaN
# 1        B          Mitosis    NaN
# 2        B          Mitosis    NaN
# 3        B          Mitosis    NaN
# 4        B          Mitosis    NaN
# 5        M          Mitosis    NaN
# 6        B          Mitosis    NaN
# 7        B          Mitosis    NaN
# 8        B          Mitosis    NaN
# 9        B          Mitosis    NaN
# 10       B          Mitosis    NaN
# 11       B          Mitosis    NaN
# 12       M          Mitosis    NaN
# 13       B          Mitosis    NaN
# 14       M          Mitosis    NaN
# 15       M          Mitosis    NaN
# 16       B          Mitosis    NaN
# 17       B          Mitosis    NaN
# 18       M          Mitosis    NaN
# 19       B          Mitosis    NaN
# 20       M          Mitosis    NaN
# 21       M          Mitosis    NaN
# 22       B          Mitosis    NaN
# 23       M          Mitosis    NaN
# 24       B          Mitosis    NaN
# 25       M          Mitosis    NaN
# 26       B          Mitosis    NaN
# 27       B          Mitosis    NaN
# 28       B          Mitosis    NaN
# 29       B          Mitosis    NaN
# ...    ...              ...    ...
# 1368     M  slump_thickness    5.0
# 1369     M  slump_thickness    3.0
# 1370     B  slump_thickness    3.0
# 1371     B  slump_thickness    2.0
# 1372     B  slump_thickness    5.0
# 1373     B  slump_thickness    1.0
# 1374     B  slump_thickness    4.0
# 1375     B  slump_thickness    1.0
# 1376     B  slump_thickness    5.0
# 1377     B  slump_thickness    1.0
# 1378     B  slump_thickness    2.0
# 1379     M  slump_thickness   10.0
# 1380     M  slump_thickness    5.0
# 1381     B  slump_thickness    5.0
# 1382     B  slump_thickness    1.0
# 1383     B  slump_thickness    1.0
# 1384     B  slump_thickness    1.0
# 1385     B  slump_thickness    1.0
# 1386     B  slump_thickness    3.0
# 1387     B  slump_thickness    4.0
# 1388     B  slump_thickness    1.0
# 1389     B  slump_thickness    1.0
# 1390     M  slump_thickness    5.0
# 1391     B  slump_thickness    3.0
# 1392     B  slump_thickness    3.0
# 1393     B  slump_thickness    3.0
# 1394     B  slump_thickness    2.0
# 1395     M  slump_thickness    5.0
# 1396     M  slump_thickness    4.0
# 1397     M  slump_thickness    4.0
#
# [1398 rows x 3 columns]

# %%
# y = target
# data_dia = y
data = x
# # data_n_2 = (data - data.mean()) / (data.std())              # standardization
# # data = pd.concat([y,data.iloc[:,0:10]],axis=1)
# data
data = pd.melt(data,id_vars="Class",
                    var_name="features",
                    value_name="value")
print data
plt.figure(figsize=(10,10))
sns.violinplot(x="features", y="value", hue="Class", data=data,split=True, inner="quart")
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-9bd075fe11c9> in <module>()
#       7 data = pd.melt(data,id_vars="Class",
#       8                     var_name="features",
# ----> 9                     value_name="value")
#      10 print data
#      11 plt.figure(figsize=(10,10))
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/reshape/reshape.pyc in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#     755     mdata = {}
#     756     for col in id_vars:
# --> 757         mdata[col] = np.tile(frame.pop(col).values, K)
#     758
#     759     mcolumns = id_vars + var_name + [value_name]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in pop(self, item)
#     671         3  monkey        NaN
#     672         """
# --> 673         result = self[item]
#     674         del self[item]
#     675         try:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
