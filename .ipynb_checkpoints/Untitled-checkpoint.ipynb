# %%
from Tkinter import *

root = Tk()

root.geometry('{}x{}'.format(1000, 1000))

label1 = Label( root, text="texture_mean")
texture_mean = Entry(root, bd =2)

label2 = Label( root, text="area_mean")
area_mean = Entry(root, bd =5)

label3 = Label( root, text="smoothness_mean")
smoothness_mean = Entry(root, bd =5)

label4 = Label( root, text="concavity_mean")
concavity_mean = Entry(root, bd =5)

label5 = Label( root, text="symmetry_mean")
symmetry_mean = Entry(root, bd =5)

label6 = Label( root, text="fractal_dimension_mean")
fractal_dimension_mean = Entry(root, bd =5)

label7 = Label( root, text="texture_se")
texture_se = Entry(root, bd =5)

label8 = Label( root, text="area_se")
area_se = Entry(root, bd =5)

label9 = Label( root, text="smoothness_se")
smoothness_se = Entry(root, bd =5)

label10 = Label( root, text="concavity_se")
concavity_se = Entry(root, bd =5)

label11 = Label( root, text="symmetry_se")
symmetry_se = Entry(root, bd =5)

label12 = Label( root, text="fractal_dimension_se")
fractal_dimension_se = Entry(root, bd =5)

label13 = Label( root, text="smoothness_worst")
smoothness_worst = Entry(root, bd =5)

label14 = Label( root, text="concavity_worst")
concavity_worst = Entry(root, bd =5)

label15 = Label( root, text="symmetry_worst")
symmetry_worst = Entry(root, bd =5)

label16 = Label( root, text="fractal_dimension_worst")
fractal_dimension_worst = Entry(root, bd =5)

def getDate():
    print texture_mean.get()
#     print E2.get()
#     print E3.get()

submit = Button(root, text ="Submit", command = getDate)

label1.pack()

texture_mean.pack()

label2.pack()
area_mean.pack()

label3.pack()
smoothness_mean.pack()

label4.pack()
concavity_mean.pack()

label5.pack()
symmetry_mean.pack()

label6.pack()
fractal_dimension_mean.pack()

label7.pack()
texture_se.pack()

label8.pack()
area_se.pack()

label9.pack()
smoothness_se.pack()

label10.pack()
concavity_se.pack()

label11.pack()
symmetry_se.pack()

label12.pack()
fractal_dimension_se.pack()

label13.pack()
smoothness_worst.pack()

label14.pack()
concavity_worst.pack()

label15.pack()
symmetry_worst.pack()

label16.pack()
fractal_dimension_worst.pack()


submit.pack(side =BOTTOM) 
root.mainloop()

# %%
import Tkinter
import csv

root = Tkinter.Tk()

# open file
with open("breast-cancer-wisconsin.data.csv") as file:
   reader = csv.reader(file)

   # r and c tell us where to grid the labels
   r = 0
   for col in reader:
      c = 0
      for row in col:
         # i've added some styling
         label = Tkinter.Label(root, width = 10, height = 2, \
                               text = row, relief = Tkinter.RIDGE)
         label.grid(row = r, column = c)
         c += 1
      r += 1

root.mainloop()

# %%
from Tkinter import *

root = Tk()

root.geometry('{}x{}'.format(400, 200))

label1 = Label( root, text="texture_mean")
texture_mean = Entry(root, bd =2)

label2 = Label( root, text="area_mean")
area_mean = Entry(root, bd =5)

label3 = Label( root, text="smoothness_mean")
smoothness_mean = Entry(root, bd =5)

label4 = Label( root, text="concavity_mean")
concavity_mean = Entry(root, bd =5)

label5 = Label( root, text="symmetry_mean")
symmetry_mean = Entry(root, bd =5)

label6 = Label( root, text="fractal_dimension_mean")
fractal_dimension_mean = Entry(root, bd =5)

label7 = Label( root, text="texture_se")
texture_se = Entry(root, bd =5)

label8 = Label( root, text="area_se")
area_se = Entry(root, bd =5)

label9 = Label( root, text="smoothness_se")
smoothness_se = Entry(root, bd =5)

label10 = Label( root, text="concavity_se")
concavity_se = Entry(root, bd =5)

label11 = Label( root, text="symmetry_se")
symmetry_se = Entry(root, bd =5)

label12 = Label( root, text="fractal_dimension_se")
fractal_dimension_se = Entry(root, bd =5)

label13 = Label( root, text="smoothness_worst")
smoothness_worst = Entry(root, bd =5)

label14 = Label( root, text="concavity_worst")
concavity_worst = Entry(root, bd =5)

label15 = Label( root, text="symmetry_worst")
symmetry_worst = Entry(root, bd =5)

label16 = Label( root, text="fractal_dimension_worst")
fractal_dimension_worst = Entry(root, bd =5)

def getDate():
    print texture_mean.get()
#     print E2.get()
#     print E3.get()

w = Message(root, text="this is a message", width=150)
w.pack()


root.mainloop()
